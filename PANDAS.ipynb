# %% [markdown]
# <a href="https://colab.research.google.com/github/maryb2002/Exercises-about-Pandas-Lib/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas has two data structer
#SERIES

import pandas as pd
tmp=pd.Series(data=[100, 200, 300, 400], index=['carlos', 'juan', 'marui', 'rosita'])

# %%
print(tmp)
# Out:
# carlos    100
# juan      200
# marui     300
# rosita    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp[-2])
print(tmp['marui'])
# Out:
# 300
# 300

# %%
tmp*2
# Out:
# carlos    200
# juan      400
# marui     600
# rosita    800
# dtype: int64

# %%
tmp[[1,2,3]]
print(tmp[[1,2,3]])
# Out:
# juan      200
# marui     300
# rosita    400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['carlos', 'juan', 'marui', 'rosita'], dtype='object')

# %%
d= {'one':pd.Series([100, 200, 300], index=['aple', 'ball', 'clock']), 'two':pd.Series([111, 222, 333], index=['aple', 'ball', 'cerill'])}

# %%
df=pd.DataFrame(d)

# %%
df.shape
# Out:
# (4, 2)

# %%
df
# Out:
#           one    two
# aple    100.0  111.0
# ball    200.0  222.0
# cerill    NaN  333.0
# clock   300.0    NaN

# %%
df.index
# Out:
# Index(['aple', 'ball', 'cerill', 'clock'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
#OPERACIONES BÀSICAS
#MULTIPLICACIÒN
df['tres']=df['one']*df['two']
df
# Out:
#           one    two     tres
# aple    100.0  111.0  11100.0
# ball    200.0  222.0  44400.0
# cerill    NaN  333.0      NaN
# clock   300.0    NaN      NaN

# %%
#SUMA
df['four']=df['one']+df['two']
df
# Out:
#           one    two     tres   four
# aple    100.0  111.0  11100.0  211.0
# ball    200.0  222.0  44400.0  422.0
# cerill    NaN  333.0      NaN    NaN
# clock   300.0    NaN      NaN    NaN

# %%
df['filtro']=df['one']>105
df
# Out:
#           one    two     tres   four  filtro
# aple    100.0  111.0  11100.0  211.0   False
# ball    200.0  222.0  44400.0  422.0    True
# cerill    NaN  333.0      NaN    NaN   False
# clock   300.0    NaN      NaN    NaN    True

# %%
#ELIMINAR COLUMNA CON DEL
del df['tres']

# %%
df
# Out:
#           one    two   four  filtro
# aple    100.0  111.0  211.0   False
# ball    200.0  222.0  422.0    True
# cerill    NaN  333.0    NaN   False
# clock   300.0    NaN    NaN    True

# %%
#ELIMINAR COLUMNA CON POP
df2=df.pop('four')

# %%
df
# Out:
#           one    two  filtro
# aple    100.0  111.0   False
# ball    200.0  222.0    True
# cerill    NaN  333.0   False
# clock   300.0    NaN    True

# %% [markdown]
# ESTUDIO DE CASOS - CASE STUDY

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
#PARA IMPRIMIR LOS 10 PRIMEROS
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
#PARA ENFOCARSE EN UNA SOLA COLUMNA
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
#EL HEAD ES PARA IMPRIMIR DE ARRIBA PARA ABAJO
ratings.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
#EL HEAD ES PARA IMPRIMIR DE ABAJO PARA ARRIBA
ratings.tail(5)
# Out:
#          userId  movieId  rating   timestamp
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418

# %%
tags.tail(10)
# Out:
#         userId  movieId                               tag   timestamp
# 465554  138446     3489                visually appealing  1358983822
# 465555  138446     7045                   family friendly  1358983660
# 465556  138446     7045  Scary Movies To See on Halloween  1358983660
# 465557  138446     7164                         Peter Pan  1358983855
# 465558  138446     7164                visually appealing  1358983855
# 465559  138446    55999                           dragged  1358983772
# 465560  138446    55999                     Jason Bateman  1358983778
# 465561  138446    55999                            quirky  1358983778
# 465562  138446    55999                               sad  1358983772
# 465563  138472      923                     rise to power  1194037967

# %%
import pandas as pd

# %%
movies1='/content/movies.csv'
ratigns1='/content/ratings.csv'
tags1='/content/tags.csv'

# %%
movies=pd.read_csv(movies1)
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
tags=pd.read_csv(tags)
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
ratings.shape
# Out:
# (2000000, 4)

# %%
movies.shape
# Out:
# (9742, 3)

# %%
tags.shape
# Out:
# (3683, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
tags.head(5)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell
# 3       2    89774     Boxing story
# 4       2    89774              MMA

# %%
ratings.iloc[6]
# Out:
# userId       1.0
# movieId    151.0
# rating       4.0
# Name: 6, dtype: float64

# %%
print(ratings.iloc[[20,40,50]])
# Out:
#     userId  movieId  rating
# 20       1      924     3.5
# 40       1     1240     4.0
# 50       1     1291     3.5

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000000e+06  2.000000e+06  2.000000e+06
# mean   6.763309e+03  8.717178e+03  3.518678e+00
# std    3.908996e+03  1.921823e+04  1.050556e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.374000e+03  9.040000e+02  3.000000e+00
# 50%    6.743000e+03  2.153000e+03  3.500000e+00
# 75%    1.015825e+04  4.661000e+03  4.000000e+00
# max    1.356700e+04  1.307680e+05  5.000000e+00

# %%
ratings.shape
# Out:
# (2000000, 3)

# %%
print(ratings['rating'].min())
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.005013 -0.005718
# movieId  0.005013  1.000000  0.003717
# rating  -0.005718  0.003717  1.000000

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5

# %%
filter=ratings ['rating']>5

# %%
filter.any()
# Out:
# False

# %%
mask=ratings['rating']<3

# %%
print(mask.any())
# Out:
# True

# %%
aux=ratings[mask]
print(aux.shape)
# print()
print(aux.head(3))
# Out:
# (354798, 3)
#      userId  movieId  rating
# 186       2      891     2.0
# 203       2     1969     2.0
# 204       2     1970     2.0

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
ratings.hist(column='rating',figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
is_animation=movies['genres'].str.contains('Animation')

# %%
newMovies=movies[is_animation]

# %%
newMovies.head(10)
# Out:
#      movieId                                   title  \
# 0          1                        Toy Story (1995)
# 12        13                            Balto (1995)
# 44        48                       Pocahontas (1995)
# 205      239                   Goofy Movie, A (1995)
# 272      313               Swan Princess, The (1994)
# 322      364                   Lion King, The (1994)
# 483      551  Nightmare Before Christmas, The (1993)
# 488      558                  Pagemaster, The (1994)
# 506      588                          Aladdin (1992)
# 511      594  Snow White and the Seven Dwarfs (1937)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 44          Animation|Children|Drama|Musical|Romance
# 205                Animation|Children|Comedy|Romance
# 272                               Animation|Children
# 322  Adventure|Animation|Children|Drama|Musical|IMAX
# ...

# %%
tags='/content/tags.csv'
tags=pd.read_csv(tags)

# %%
tags.head(5)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags['informationDateTime']=pd.to_datetime(tags['timestamp'],unit='s')

# %%
tags.head(10)
# Out:
#    userId  movieId                tag   timestamp informationDateTime
# 0       2    60756              funny  1445714994 2015-10-24 19:29:54
# 1       2    60756    Highly quotable  1445714996 2015-10-24 19:29:56
# 2       2    60756       will ferrell  1445714992 2015-10-24 19:29:52
# 3       2    89774       Boxing story  1445715207 2015-10-24 19:33:27
# 4       2    89774                MMA  1445715200 2015-10-24 19:33:20
# 5       2    89774          Tom Hardy  1445715205 2015-10-24 19:33:25
# 6       2   106782              drugs  1445715054 2015-10-24 19:30:54
# 7       2   106782  Leonardo DiCaprio  1445715051 2015-10-24 19:30:51
# 8       2   106782    Martin Scorsese  1445715056 2015-10-24 19:30:56
# 9       7    48516       way too long  1169687325 2007-01-25 01:08:45
